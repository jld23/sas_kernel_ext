# %% [markdown]
# # Code example that has only log output

# %%
proc sort data=sashelp.class out=outgoing.class;
by sex age;
run;
# Out:
# 50   ods listing close;ods html5 (id=saspy_internal) options(bitmap_mode='inline') device=svg style=HTMLBlue; ods graphics on /
# 50 ! outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: sashtml4.htm
# 51
# 52   proc sort data=sashelp.class out=outgoing.class;
# ERROR: Libref OUTGOING is not assigned.
# 53   by sex age;
# 54   run;
#
# NOTE: The SAS System stopped processing this step because of errors.
# NOTE: PROCEDURE SORT used (Total process time):
#       real time           0.00 seconds
#       cpu time            0.00 seconds
#
# 55
# 56   ods html5 (id=saspy_internal) close;ods listing;
# 57
# ERROR: Libref OUTGOING is not assigned. None

# %%
proc sort data=sashelp.class out=class;
by sex age;
run;
# Out:
# 0 0
# 42   ods listing close;ods html5 (id=saspy_internal) options(bitmap_mode='inline') device=svg style=HTMLBlue; ods graphics on /
# 42 ! outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: sashtml3.htm
# 43
#
#
# 44   proc sort data=sashelp.class out=class;
# 45   by sex age;
# 46   run;
#
# NOTE: There were 19 observations read from the data set SASHELP.CLASS.
# NOTE: The data set WORK.CLASS has 19 observations and 5 variables.
# NOTE: PROCEDURE SORT used (Total process time):
#       real time           0.00 seconds
#       cpu time            0.00 seconds
#
#
# 47
# 48   ods html5 (id=saspy_internal) close;ods listing;
# 49

# %% [markdown]
# # Jupyter Kernel to show the SAS Log
# This is the log from the last executed cell (likely the one above)

# %%
%showLog
# Out:
# 0 0
# 89   ods listing close;ods html5 (id=saspy_internal) options(bitmap_mode='inline') device=svg style=HTMLBlue; ods graphics on /
# 89 ! outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: sashtml9.htm
# 90
# 91   proc means data=sashelp.heart;
# 92   run;
#
# NOTE: There were 5209 observations read from the data set SASHELP.HEART.
# NOTE: PROCEDURE MEANS used (Total process time):
#       real time           0.03 seconds
#       cpu time            0.04 seconds
#
#
# 93   proc foo;
# ERROR: Procedure FOO not found.
# 94   run;
#
# NOTE: The SAS System stopped processing this step because of errors.
# NOTE: PROCEDURE FOO used (Total process time):
#       real time           0.00 seconds
#       cpu time            0.00 seconds
#
# 95
# 96   ods html5 (id=saspy_internal) close;ods listing;
# 97

# %% [markdown]
# # Code example that has Log and LST output

# %%
proc means data=sashelp.air;
run;
# Out:
# 0 32546
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS V.04.00" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
%showLog
# Out:
# 0 0
# 89   ods listing close;ods html5 (id=saspy_internal) options(bitmap_mode='inline') device=svg style=HTMLBlue; ods graphics on /
# 89 ! outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: sashtml9.htm
# 90
# 91   proc means data=sashelp.heart;
# 92   run;
#
# NOTE: There were 5209 observations read from the data set SASHELP.HEART.
# NOTE: PROCEDURE MEANS used (Total process time):
#       real time           0.03 seconds
#       cpu time            0.04 seconds
#
#
# 93   proc foo;
# ERROR: Procedure FOO not found.
# 94   run;
#
# NOTE: The SAS System stopped processing this step because of errors.
# NOTE: PROCEDURE FOO used (Total process time):
#       real time           0.00 seconds
#       cpu time            0.00 seconds
#
# 95
# 96   ods html5 (id=saspy_internal) close;ods listing;
# 97

# %% [markdown]
# # Code with Log and LST and

# %%
proc means data=sashelp.heart;
run;
proc foo;
run;
# Out:
# 1 34047
# NOTE: PROCEDURE MEANS used (Total process time):
#       real time           0.03 seconds
#       cpu time            0.04 seconds
#
#
# 37   proc foo;
# ERROR: Procedure FOO not found.
# 38   run;
#
# NOTE: The SAS System stopped processing this step because of errors.
# NOTE: PROCEDURE FOO used (Total process time):
#       real time           0.00 seconds
# None
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS V.04.00" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# ...

# %%
%showLog
# Out:
# 0 0
# 89   ods listing close;ods html5 (id=saspy_internal) options(bitmap_mode='inline') device=svg style=HTMLBlue; ods graphics on /
# 89 ! outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: sashtml9.htm
# 90
# 91   proc means data=sashelp.heart;
# 92   run;
#
# NOTE: There were 5209 observations read from the data set SASHELP.HEART.
# NOTE: PROCEDURE MEANS used (Total process time):
#       real time           0.03 seconds
#       cpu time            0.04 seconds
#
#
# 93   proc foo;
# ERROR: Procedure FOO not found.
# 94   run;
#
# NOTE: The SAS System stopped processing this step because of errors.
# NOTE: PROCEDURE FOO used (Total process time):
#       real time           0.00 seconds
#       cpu time            0.00 seconds
#
# 95
# 96   ods html5 (id=saspy_internal) close;ods listing;
# 97
